# %% [markdown]
# ### This is a simple job aggerator program using web scraping technique. Here we are collecting job details from three job portals(shine.com, naukri.com, timesjobs.com). User have to just input 3 details i.e., job profile(mandatory), experience and location (these 2 are optional).This program aggregates the details from first page of all the portals sorted by relevance.

# %%
# Importing required libraries
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from urllib.parse import urljoin
from requests_html import AsyncHTMLSession
import pyppdf.patch_pyppeteer

# %%
# Code for getting profile name, experience and location
while(True):
    profile=input('Please enter the profile name or keyword for job search: ')
    experience=input('Please enter your experience level in years: ')
    location=input('Please enter a location for job search: ')

    # Profile name can not be empty
    if profile== '':
        print('\nProfile name cannot be empty!!!\nTry searching again!\n')
        continue
    else:
        break
    # Experience should be in numbers so checking it
    if experience !='':
        try:
            int(experience)
        except:
            print('\nEnter experience in numbers please!!!\nTry searching again!\n')
            continue
    else:
        break
# Out:
# Please enter the profile name or keyword for job search: data scientist
# Please enter your experience level in years: 3
# Please enter a location for job search: mumbai

# %%
# Creating four lists for the purpose of data collection
profile_name=[]
company_name=[]
post_date=[]
link =[]

# header will be used in web scraping(it is your system's id for accessing web )
header={'User-Agetn':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0'}

# %%
# Below is the function for aggregating the data from shine.com job portal.
def shine_data(prof,exp,loc):
    prof=prof.strip()
    prof=prof.split()
    prof.append('jobs')
    prof='-'.join(prof)
    
    exp=exp.strip()
    loc=loc.strip()
    
    if exp !='':
        if int(exp)==0:
            exp="2"
        else:
            exp=str(int(exp)+3)
            
    loc=loc.strip()
    
    # Creating link with our search keywords
    if location == "":
        shine_url='https://www.shine.com/job-search/'+prof+'?loc='+loc+'&minexp='+exp
    else:
        shine_url='https://www.shine.com/job-search/'+prof+'-in-'+loc+'i?loc='+loc+'&minexp='+exp
    
    # Creating requests for scraping
    res=requests.get(shine_url, headers=header)
    if res.status_code!=200:
        return "Shine data NA"
    else:
        res_content=res.content
        soup=bs(res_content,'lxml')
        jobs_shine=soup.find_all('a',{'class':'cls_searchresult_a searchresult_link'})
        
        for jobs in jobs_shine:
            profile_name.append((jobs.find('h3').text).strip().replace(u'\xa0', ' '))
            company_name.append((jobs.find('li',{'class':'snp_cnm cls_cmpname cls_jobcompany'}).text).strip())
            post_date.append((jobs.find('li',{'class':'time share_links jobDate'}).text).strip())
            link.append(urljoin(shine_url,jobs['href']))
        return "done"

# %%
# Creating function for scraping from naukri.com
# As naukri uses javascript so we used AsyncHTMLsession to extract the data and hence the function had to be 
# asynchronous function.
async def naukri_data(prof,exp,loc):
    prof=prof.strip()
    prof=prof.split()
    prof.append('jobs')
    prof='-'.join(prof)
    
    exp=exp.strip()
    loc=loc.strip()
    
    # Creating link with our search keywords    
    if location == "":
        naukri_url='https://www.naukri.com/'+prof+'?k='+prof+'&experience'+exp
    else:
        naukri_url='https://www.naukri.com/'+prof+'-in-'+loc+'?k='+prof+'&l='+loc+'&experience='+exp
    
    # Creating html_requests session for scraping
    session=AsyncHTMLSession()
    res=await session.get(naukri_url, headers=header)
    
    if res.status_code!=200:
        return "Shine data NA"
    else:
        await res.html.arender()

        for i in range(len(res.html.find('.jobTupleHeader'))):
            profile_name.append(res.html.find('.jobTupleHeader')[i].find('a')[0].text)
            company_name.append(res.html.find('.jobTupleHeader')[i].find('[href]')[1].attrs['title'])
            post_date.append(res.html.find('.jobTupleFooter.mt-20')[i].find('span.fleft.fw500')[-1].text)
            link.append(res.html.find('.jobTupleHeader')[i].find('[href]')[0].attrs['href'])
        await session.close()
        return "done"

# %%
# Scraping from timesjobs.com web portal.
def timesjobs_data(prof,exp,loc):
    prof=prof.strip()
    prof=prof.split()
    prof='+'.join(prof)
    
    exp=exp.strip()
    loc=loc.strip()
        
    if location == "":
        tj_url='https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords='+prof+'&txtLocation=&cboWorkExp1='+exp
    else:
        tj_url='https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords='+prof+'&txtLocation='+loc+'&cboWorkExp1='+exp
        
    res=requests.get(tj_url, headers=header)
    if res.status_code!=200:
        return "Timesjobs data NA"
    else:
        res_content=res.content
        soup=bs(res_content,'lxml')
        
        for i in range(len(soup.find_all('li',{'class':'clearfix job-bx wht-shd-bx'}))):
            # Profile Name
            profile_name.append(soup.find_all('li',{'class':'clearfix job-bx wht-shd-bx'})[i].find_all('a')[0].text.strip())
            company_name.append(soup.find_all('li',{'class':'clearfix job-bx wht-shd-bx'})[i].find_all('h3')[0].text.strip())
            post_date.append(soup.find_all('span',{'class':'sim-posted'})[i].find_all('span')[-1].text.strip())
            link.append(soup.find_all('li',{'class':'clearfix job-bx wht-shd-bx'})[i].find_all('a')[0]['href'])
        return "done"

# %%
# Executing functions
shine_data(profile,experience,location)
# Out:
# 'done'

# %%
await naukri_data(profile,experience,location)
# Out:
# 'done'

# %%
timesjobs_data(profile,experience,location)
# Out:
# 'done'

# %%
# Setting display option maximum for columns and rows so that no rows or columns are discarded
pd.set_option('display.max_rows',100)
pd.set_option('display.max_colwidth', None)

job_listing=pd.DataFrame({'Profile':profile_name,'Company':company_name,'Recency':post_date,'URL':link})

# %%
job_listing
# Out:
#                                                                    Profile  \
# 0                                                           Data Scientist
# 1                                                           Data Scientist
# 2                                                           Data Scientist
# 3                                                           Data Scientist
# 4                                                           Data Scientist
# 5                                                           Data Scientist
# 6                                             AI Developer/ Data Scientist
# 7                                                           Data Scientist
# 8                                                           Data Scientist
# 9                                                           Data Scientist
# 10                                                          Data Scientist
# 11                                                          Data Scientist
# 12                                      Data Analyst, Marketing Specialist
# 13               Work From Home (Data Entry & Manual ) Earn upto Rs.80K PM
# 14                                                            Data Analyst
# 15                              Deep Data Marketing / Digital Data Analyst
# 16                                                   Senior Data Scientist
# 17                                   BBRC-DBTS- SENIOR ASSOCIATE SCIENTIST
# 18                                   BBRC-DBTS- SENIOR ASSOCIATE SCIENTIST
# 19                                                            Data Analyst
# 20                                                          Data Scientist
# 21                                                          Data Scientist
# 22     AM/Manager Data Scientist @ Tech Mahindra Business Service (Mumbai)
# 23                                      Data Scientist - Nlp/deep Learning
# 24  Looking For Data scientist-mumbai-c2h with Level5-only Immediate-15day
# 25                                                          Data Scientist
# 26                                      Data Scientist- Financial Services
# 27                                                     Lead Data Scientist
# 28                                                          Data Scientist
# 29                               Con - Big Data Analytics + Data Scientist
# 30          Job | Data Scientist | Machine Learning & Statistical Analysis
# 31                                Data Scientist - Mumbai - Action Covid19
# 32            Data Scientist (only Local Candidates from Mumbai Can Apply)
# 33                             Data Scientist - Python/predictive Modeling
# 34     Senior Data Scientist - Artificial Intelligence - Online/ Ecommerce
# 35           Data Scientist - Machine Learning & R - BFSI - IIT/ ISI/ IISc
# 36                                     Data Scientist, Lead Data Scientist
# 37                                                          Data Scientist
# 38                          Excellent Opportunity- Data Scientist @ Mumbai
# 39                      Sr Data Scientist - Computer Vision, Deep Learning
# 40                                                          Data Scientist
# 41                                                          Data Scientist
# 42                                                          Data Scientist
# 43                                                          Data Scientist
# 44                                                          Data Scientist
# 45                                                          Data Scientist
# 46                                                          Data Scientist
# 47                                                          Data Scientist
# 48                                                          Data Scientist
# 49                                                          Data Scientist
# 50                                                          Data Scientist
# 51                                                          Data Scientist
# 52                                                          Data Scientist
# 53                                                          Data Scientist
# 54                                                          Data Scientist
# 55                                                          Data Scientist
# 56                                                          Data Scientist
# 57                                                     Data Data Scientist
# 58                                             Data Scientist - R Modeling
# 59                                Data Scientist  ( Analytics Specialist )
# 60                                                  Analyst Data Scientist
# 61                                          Junior / Senior Data Scientist
# 62                                         Data Scientist - (  IIT / ISI )
# 63                                             Data Scientist  ( Product )
# 64                                                  Jr Data Scientist- Dox
#
#                                         Company              Recency  \
# 0                     NEEMTREE INTERNET PVT LTD         Jun 17, 2020
# 1                         Denave India Pvt Ltd.         Jun 17, 2020
# 2                                        Bprise         Jun 13, 2020
# 3                         Angel Broking Limited         Jun 12, 2020
# 4                         BigTree Entertainment         Jun 15, 2020
# 5                                      Analytos         Jun 11, 2020
# 6                OPEXAI BUSINESS CONSULTING LLP         Jun 11, 2020
# 7                         BigTree Entertainment         Jun 13, 2020
# 8                 ALLERIN TECHNOLOGIES Pvt Ltd.         Jun 04, 2020
# 9                                    Mastek Ltd         May 18, 2020
# 10                            Seven Consultancy         May 17, 2020
# 11                ALLERIN TECHNOLOGIES Pvt Ltd.         Jun 04, 2020
# 12                                       Gitlab         Jun 12, 2020
# 13  MINANSHIKA SOFTECH SOLUTION PRIVATE LIMITED         Jun 17, 2020
# 14                                  Toptal, LLC         Jun 09, 2020
# 15                                 Asymmetrique         Jun 15, 2020
# 16                                  JoinHandsHR         Apr 27, 2020
# 17                                       Sygene         Jun 16, 2020
# 18                Syngene International Limited         Jun 16, 2020
# 19                         Augmenter Consulting         Jun 16, 2020
# 20          Wcities Content Solutions Pvt. Ltd.           7 Days Ago
# 21                  Bigshyft Hiring for Arya.ai           8 Days Ago
# 22      Tech Mahindra Business Services Limited         30+ Days Ago
# 23                                       TalPro         30+ Days Ago
# 24                       RANDSTAD INDIA PVT LTD         30+ Days Ago
# 25                                    NSEIT LTD         30+ Days Ago
# 26                           Mastermind Network          28 Days Ago
# 27                                     Snaphunt          15 Days Ago
# 28         Bigshyft Hiring for Global Gene Corp          10 Days Ago
# 29          Pylon Management Consulting Pvt Ltd           8 Days Ago
# 30                             Manmuk Creations           6 Days Ago
# 31                     Infinite Analytics, Inc.         30+ Days Ago
# 32      Gladwin Analytics Private Limited (OPC)         30+ Days Ago
# 33                                Serving Skill          21 Days Ago
# 34                               Change Leaders         30+ Days Ago
# 35                    hCapital Executive Search         30+ Days Ago
# 36                          KSIRIUS CONSULTANTS         30+ Days Ago
# 37                        Fractal Analytics Ltd         30+ Days Ago
# 38             Peoplefy Infosolutions Pvt. Ltd.          15 Days Ago
# 39                            HERE Technologies           4 Days Ago
# 40                             Analytics Vidhya  Posted few days ago
# 41                                     Hookfish     Posted 1 day ago
# 42                       Sanofi-aventis Pvt Ltd    Posted 2 days ago
# 43                       Sanofi-aventis Pvt Ltd    Posted 2 days ago
# 44                       Sanofi-aventis Pvt Ltd    Posted 3 days ago
# 45                                         PayU  Posted few days ago
# 46                          HyreFox Consultants  Posted few days ago
# 47                                    GenieTalk    Posted 4 days ago
# 48                       CrossTab IT Consulting  Posted few days ago
# 49                                   Mastek Ltd  Posted few days ago
# 50                                 Michael Page  Posted few days ago
# 51                     Harjai Computers Pvt Ltd  Posted few days ago
# 52                             Analytics Vidhya  Posted few days ago
# 53                      Tata Communications Ltd    Posted 4 days ago
# 54                             Analytics Vidhya  Posted few days ago
# 55  CANVAS27.com Consultant\r\n     (More Jobs)   Posted a month ago
# 56             CANVAS27.com\r\n     (More Jobs)   Posted a month ago
# 57                                   BOOKMYSHOW  Posted few days ago
# 58                 Golden Opportunities Pvt Ltd  Posted few days ago
# 59                           TransOrg Analytics  Posted few days ago
# 60          CAMSDATA Technologies India Pvt Ltd  Posted few days ago
# 61                             Analytics Vidhya  Posted few days ago
# 62                             Analytics Vidhya  Posted few days ago
# 63                             Analytics Vidhya  Posted few days ago
# 64               ZODIAC HR CONSULTANTS PVT LTD.  Posted few days ago
#
#                                                                                                                                                                                                                                URL
# 0                                                                                                                                                    https://www.shine.com/jobs/data-scientist/neemtree-internet-pvt-ltd/10402056/
# 1                                                                                                                                                         https://www.shine.com/jobs/data-scientist/denave-india-pvt-ltd/10566781/
# 2                                                                                                                                                                       https://www.shine.com/jobs/data-scientist/bprise/10794585/
# 3                                                                                                                                                        https://www.shine.com/jobs/data-scientist/angel-broking-limited/10058390/
# 4                                                                                                                                                         https://www.shine.com/jobs/data-scientist/bigtree-entertainment/9874466/
# 5                                                                                                                                                                     https://www.shine.com/jobs/data-scientist/analytos/10572504/
# 6                                                                                                                                  https://www.shine.com/jobs/ai-developer-data-scientist/opexai-business-consulting-llp/10658144/
# 7                                                                                                                                                         https://www.shine.com/jobs/data-scientist/bigtree-entertainment/9874456/
# 8                                                                                                                                                 https://www.shine.com/jobs/data-scientist/allerin-technologies-pvt-ltd/10186210/
# 9                                                                                                                                                                   https://www.shine.com/jobs/data-scientist/mastek-ltd/10817872/
# 10                                                                                                                                                           https://www.shine.com/jobs/data-scientist/seven-consultancy/10375185/
# 11                                                                                                                                                https://www.shine.com/jobs/data-scientist/allerin-technologies-pvt-ltd/10186228/
# 12                                                                                                                                                   https://www.shine.com/jobs/data-analyst-marketing-specialist/gitlab/10848540/
# 13                                                                                         https://www.shine.com/jobs/work-from-home-data-entry-manual-jobs-earn-upto-rsk-pm/minanshika-softech-solution-private-limited/10803141/
# 14                                                                                                                                                                    https://www.shine.com/jobs/data-analyst/toptal-llc/10844265/
# 15                                                                                                                                      https://www.shine.com/jobs/deep-data-marketing-digital-data-analyst/asymmetrique/10295385/
# 16                                                                                                                                                          https://www.shine.com/jobs/senior-data-scientist/joinhandshr/10196381/
# 17                                                                                                                                                https://www.shine.com/jobs/bbrc-dbts-senior-associate-scientist/sygene/10826790/
# 18                                                                                                                         https://www.shine.com/jobs/bbrc-dbts-senior-associate-scientist/syngene-international-limited/10812787/
# 19                                                                                                                                                          https://www.shine.com/jobs/data-analyst/augmenter-consulting/10306532/
# 20                                                         https://www.naukri.com/job-listings-data-scientist-wcities-content-solutions-pvt-ltd-mumbai-2-to-6-years-050919010269?src=jobsearchDesk&sid=15924278993493628&xp=1&px=1
# 21                                                               https://www.naukri.com/job-listings-data-scientist-bigshyft-hiring-for-arya-ai-mumbai-2-to-5-years-090620900332?src=jobsearchDesk&sid=15924278993493628&xp=2&px=1
# 22  https://www.naukri.com/job-listings-am-manager-data-scientist-tech-mahindra-business-service-mumbai-tech-mahindra-business-services-limited-mumbai-3-to-8-years-220420005762?src=jobsearchDesk&sid=15924278993493628&xp=3&px=1
# 23                                                                  https://www.naukri.com/job-listings-data-scientist-nlp-deep-learning-talpro-mumbai-1-to-4-years-260320905267?src=jobsearchDesk&sid=15924278993493628&xp=4&px=1
# 24            https://www.naukri.com/job-listings-looking-for-data-scientist-mumbai-c2h-with-level5-only-immediate-15day-randstad-india-pvt-ltd-mumbai-3-to-8-years-290420001389?src=jobsearchDesk&sid=15924278993493628&xp=5&px=1
# 25                                                                                 https://www.naukri.com/job-listings-data-scientist-nseit-ltd-mumbai-3-to-7-years-210320000402?src=jobsearchDesk&sid=15924278993493628&xp=6&px=1
# 26                                                     https://www.naukri.com/job-listings-data-scientist-financial-services-mastermind-network-mumbai-3-to-8-years-200520004305?src=jobsearchDesk&sid=15924278993493628&xp=7&px=1
# 27                                                                             https://www.naukri.com/job-listings-lead-data-scientist-snaphunt-mumbai-3-to-8-years-020620002616?src=jobsearchDesk&sid=15924278993493628&xp=8&px=1
# 28                                            https://www.naukri.com/job-listings-data-scientist-bigshyft-hiring-for-global-gene-corp-mumbai-ahmedabad-4-to-9-years-250520900830?src=jobsearchDesk&sid=15924278993493628&xp=9&px=1
# 29                               https://www.naukri.com/job-listings-con-big-data-analytics-data-scientist-pylon-management-consulting-pvt-ltd-mumbai-2-to-4-years-010620003043?src=jobsearchDesk&sid=15924278993493628&xp=10&px=1
# 30         https://www.naukri.com/job-listings-data-scientist-machine-learning-statistical-analysis-manmuk-creations-delhi-mumbai-bengaluru-bangalore-2-to-5-years-110620002829?src=jobsearchDesk&sid=15924278993493628&xp=11&px=1
# 31                                             https://www.naukri.com/job-listings-data-scientist-mumbai-action-covid19-infinite-analytics-inc-mumbai-2-to-5-years-290420003300?src=jobsearchDesk&sid=15924278993493628&xp=12&px=1
# 32        https://www.naukri.com/job-listings-data-scientist-only-local-candidates-from-mumbai-can-apply-gladwin-analytics-private-limited-opc-mumbai-3-to-5-years-080520004812?src=jobsearchDesk&sid=15924278993493628&xp=13&px=1
# 33                                                 https://www.naukri.com/job-listings-data-scientist-python-predictive-modeling-serving-skill-mumbai-2-to-6-years-170519900423?src=jobsearchDesk&sid=15924278993493628&xp=14&px=1
# 34               https://www.naukri.com/job-listings-senior-data-scientist-artificial-intelligence-online-ecommerce-change-leaders-navi-mumbai-mumbai-3-to-7-years-060320904613?src=jobsearchDesk&sid=15924278993493628&xp=15&px=1
# 35                           https://www.naukri.com/job-listings-data-scientist-machine-learning-r-bfsi-iit-isi-iisc-hcapital-executive-search-mumbai-1-to-4-years-240120910400?src=jobsearchDesk&sid=15924278993493628&xp=16&px=1
# 36                                                  https://www.naukri.com/job-listings-data-scientist-lead-data-scientist-ksirius-consultants-mumbai-1-to-6-years-210320000646?src=jobsearchDesk&sid=15924278993493628&xp=17&px=1
# 37                                                                    https://www.naukri.com/job-listings-data-scientist-fractal-analytics-ltd-mumbai-2-to-5-years-130120500756?src=jobsearchDesk&sid=15924278993493628&xp=18&px=1
# 38                              https://www.naukri.com/job-listings-excellent-opportunity-data-scientist-mumbai-peoplefy-infosolutions-pvt-ltd-mumbai-3-to-8-years-020620001841?src=jobsearchDesk&sid=15924278993493628&xp=19&px=1
# 39                           https://www.naukri.com/job-listings-sr-data-scientist-computer-vision-deep-learning-here-technologies-mumbai-mumbai-city-4-to-9-years-130620900344?src=jobsearchDesk&sid=15924278993493628&xp=20&px=1
# 40                                                                                 https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-mumbai-chennai-3-to-5-yrs-jobid-0LFSIkJaFBpzpSvf__PLUS__uAgZw==&source=srp
# 41                                                                                                 https://www.timesjobs.com/job-detail/data-scientist-hookfish-mumbai-2-to-3-yrs-jobid-YCzH0On1n3pzpSvf__PLUS__uAgZw==&source=srp
# 42                                                                                   https://www.timesjobs.com/job-detail/data-scientist-sanofi-aventis-pvt-ltd-mumbai-2-to-3-yrs-jobid-Bj24okaIuY5zpSvf__PLUS__uAgZw==&source=srp
# 43                                                                                   https://www.timesjobs.com/job-detail/data-scientist-sanofi-aventis-pvt-ltd-mumbai-2-to-3-yrs-jobid-SYpo1hRXhzFzpSvf__PLUS__uAgZw==&source=srp
# 44                                                                                   https://www.timesjobs.com/job-detail/data-scientist-sanofi-aventis-pvt-ltd-mumbai-2-to-3-yrs-jobid-Z0jeZ7ri0XFzpSvf__PLUS__uAgZw==&source=srp
# 45                                                                    https://www.timesjobs.com/job-detail/data-scientist-payu-gurgaon-mumbai-pune-bengaluru-bangalore-1-to-3-yrs-jobid-YmsksspAgaNzpSvf__PLUS__uAgZw==&source=srp
# 46                                                                                      https://www.timesjobs.com/job-detail/data-scientist-hyrefox-consultants-mumbai-0-to-3-yrs-jobid-KXrWUAuLzkVzpSvf__PLUS__uAgZw==&source=srp
# 47                                                                                 https://www.timesjobs.com/job-detail/data-scientist-genietalk-indore-mumbai-0-to-3-yrs-jobid-__SLASH__NEV3po7u7VzpSvf__PLUS__uAgZw==&source=srp
# 48                                                                                   https://www.timesjobs.com/job-detail/data-scientist-crosstab-it-consulting-mumbai-2-to-5-yrs-jobid-v8x5QhK8u2lzpSvf__PLUS__uAgZw==&source=srp
# 49                                                                                               https://www.timesjobs.com/job-detail/data-scientist-mastek-ltd-mumbai-0-to-3-yrs-jobid-1PMd38SpCztzpSvf__PLUS__uAgZw==&source=srp
# 50                                                                              https://www.timesjobs.com/job-detail/data-scientist-michael-page-mumbai-3-to-6-yrs-jobid-dqI__SLASH____PLUS__r8ohFNzpSvf__PLUS__uAgZw==&source=srp
# 51                                                                https://www.timesjobs.com/job-detail/data-scientist-harjai-computers-pvt-ltd-navi-mumbai-mumbai-pune-3-to-7-yrs-jobid-fSfiIm5ftCZzpSvf__PLUS__uAgZw==&source=srp
# 52                                                                                         https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-mumbai-1-to-4-yrs-jobid-Ddjy831tuixzpSvf__PLUS__uAgZw==&source=srp
# 53                                                                                  https://www.timesjobs.com/job-detail/data-scientist-tata-communications-ltd-mumbai-3-to-5-yrs-jobid-bO3djRTnHUpzpSvf__PLUS__uAgZw==&source=srp
# 54                                                                                         https://www.timesjobs.com/job-detail/data-scientist-analytics-vidhya-mumbai-2-to-4-yrs-jobid-a7Kxhg9WyNlzpSvf__PLUS__uAgZw==&source=srp
# 55                          https://www.timesjobs.com/job-detail/data-scientist-canvas27-com-consultant-hyderabad-secunderabad-kolkata-mumbai-noida-greater-noida-pune-1-to-6-yrs-jobid-Cb8zTTovhvRzpSvf__PLUS__uAgZw==&source=srp
# 56                                     https://www.timesjobs.com/job-detail/data-scientist-canvas27-com-hyderabad-secunderabad-kolkata-mumbai-noida-greater-noida-pune-2-to-7-yrs-jobid-fXLzTBcXnI9zpSvf__PLUS__uAgZw==&source=srp
# 57                                                                                  https://www.timesjobs.com/job-detail/data-data-scientist-bookmyshow-mumbai-3-to-6-yrs-jobid-nQ__SLASH__wLJ77b7tzpSvf__PLUS__uAgZw==&source=srp
# 58                                                                  https://www.timesjobs.com/job-detail/data-scientist-r-modeling-golden-opportunities-pvt-ltd-mumbai-0-to-3-yrs-jobid-JRcToQoFjV9zpSvf__PLUS__uAgZw==&source=srp
# 59                                                                  https://www.timesjobs.com/job-detail/data-scientist-analytics-specialist-transorg-analytics-mumbai-2-to-4-yrs-jobid-G29au7TWk7VzpSvf__PLUS__uAgZw==&source=srp
# 60      https://www.timesjobs.com/job-detail/analyst-data-scientist-camsdata-technologies-india-pvt-ltd-hyderabad-secunderabad-mumbai-chennai-pune-bengaluru-bangalore-3-to-8-yrs-jobid-XrT3esD9IHdzpSvf__PLUS__uAgZw==&source=srp
# 61                                                                           https://www.timesjobs.com/job-detail/junior-senior-data-scientist-analytics-vidhya-mumbai-1-to-4-yrs-jobid-6qr5BLSeQg1zpSvf__PLUS__uAgZw==&source=srp
# 62                                                                                 https://www.timesjobs.com/job-detail/data-scientist-iit-isi-analytics-vidhya-mumbai-1-to-4-yrs-jobid-XdQ2IKsBHgNzpSvf__PLUS__uAgZw==&source=srp
# 63                                                                                 https://www.timesjobs.com/job-detail/data-scientist-product-analytics-vidhya-mumbai-1-to-4-yrs-jobid-yWv2ahTKGr1zpSvf__PLUS__uAgZw==&source=srp
# 64                                                       https://www.timesjobs.com/job-detail/jr-data-scientist-dox-zodiac-hr-consultants-pvt-ltd-mumbai-2-to-5-yrs-jobid-jJl__PLUS__C__PLUS__yp9dxzpSvf__PLUS__uAgZw==&source=srp
